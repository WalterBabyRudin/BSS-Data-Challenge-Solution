# %% [markdown]
# ### Extract File Folders SKU 21 Data (Week 1)

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from pathlib import Path

my_data = pd.read_table('competition_data_2023_09_11.csv',delimiter=',')
sku_hist = my_data['sku'].unique()

for sku in sku_hist:
    if sku == "File Folders SKU 21":
        my_data_sku = my_data[my_data["sku"] == sku]

        filepath = Path("0911_my_data_sku_"+sku+".csv")
        filepath.parent.mkdir(parents=True, exist_ok=True)
        my_data_sku.to_csv(filepath, index=False)

sku = "File Folders SKU 21"
path_file = "0911_my_data_sku_"+sku+".csv"
my_data_sku = pd.read_table(path_file,delimiter=',')
print(my_data_sku)

# %%
# !pip install skforecast

# %% [markdown]
# ### Estimate ADSPEND for Week 1

# %%
from skforecast.ForecasterAutoreg import ForecasterAutoreg
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error

adspend      = my_data_sku["adspend"].to_numpy()
unitsordered = my_data_sku["unitsordered"].to_numpy()

steps = 9
unitsordered_shifted = np.hstack((np.zeros(steps), unitsordered))

pd_adspend      = pd.Series(adspend)
pd_unitsordered = pd.Series(unitsordered_shifted)
pd_adspend.name = "adspend"
pd_unitsordered.name = "unitsordered"


# Split data into train-test
pd_unitsordered_Tr, pd_unitsordered_Te           = pd_unitsordered[:-steps], pd_unitsordered[-steps:]



# Create and train forecaster
# ==============================================================================
regressor = RandomForestRegressor(max_depth=15, n_estimators=500, random_state=123)


forecaster = ForecasterAutoreg(
                regressor = regressor,
                lags      = 25
             )

forecaster.fit(y=pd_adspend, exog=pd_unitsordered_Tr)


# Predictions
# ==============================================================================
predictions = forecaster.predict(steps=steps, exog=pd_unitsordered_Te)


predictions = np.round(predictions)
print(predictions)

# Plot
# ==============================================================================
fig, ax = plt.subplots(figsize=(6, 2.5))
#pd_adspend_Tr.plot(ax=ax, label='train')
pd_adspend.plot(ax=ax, label='Past Adspend')
predictions.plot(ax=ax, label='Predicted Adspend')
ax.legend();


# ADSPEND_Te = np.array([17,18,15,16,17,16,15,14,14])

# %% [markdown]
# ### Estimate Competitor's Price for Week 1

# %%
comp_1_price      = my_data_sku["comp_1_price"]
steps             = 9

# Create and train forecaster
# ==============================================================================
regressor = RandomForestRegressor(max_depth=10, n_estimators=500, random_state=123)
forecaster = ForecasterAutoreg(
                regressor = regressor,
                lags      = 25
             )
forecaster.fit(y=comp_1_price)


# Predictions
# ==============================================================================
predictions = forecaster.predict(steps=steps)

predictions = np.round(predictions, 2)
# Plot
# ==============================================================================
fig, ax = plt.subplots(figsize=(6, 2.5))
comp_1_price.plot(ax=ax, label='train')
predictions.plot(ax=ax, label='predictions')
ax.legend();


print(predictions)

# comp_1_price_Te = np.array([23.02, 23.13, 23.20, 23.38, 23.75, 25.91, 25.87, 25.86, 25.87])

# %% [markdown]
# ### Begin Pricing for Week 1

# %%
from scipy.spatial.distance import cdist
import cvxpy as cp


def formulate_demand_pmf(price_Tr, comp_1_price_Tr, price_Te0, comp_1_price_Te0, sigma):
    pmf_demand_exponent = (price_Te0 - price_Tr)**2 + (comp_1_price_Te0 - comp_1_price_Tr) ** 2
    pmf_demand = np.exp(-pmf_demand_exponent/sigma)
    pmf_demand = pmf_demand / np.sum(pmf_demand)
    return pmf_demand

def WDRO_demand_calculate(pmf_demand, unitsordered_Tr, price_Te0, epsilon):
    a_1=4.43965609
    a_2=6.60097822
    N = len(pmf_demand)
    cost_hist = 0.85*price_Te0*unitsordered_Tr - (a_1 + a_2) * unitsordered_Tr

    pmf_demand = pmf_demand.reshape([-1,1])
    cost_hist  = cost_hist.reshape([-1,1])
    unitsordered_Tr = unitsordered_Tr.reshape([-1,1])

    cost_unitsordered_Tr = cdist(unitsordered_Tr, unitsordered_Tr, 'sqeuclidean')
    x = cp.Variable(N)
    gamma = cp.Variable([N,N])

    obj = cp.Minimize(cost_hist.T@x)
    constrat = [gamma >=0,
                cp.sum(cp.multiply(gamma, cost_unitsordered_Tr)) <= epsilon,
                cp.sum(gamma,1) == pmf_demand.reshape([-1,]),
                cp.sum(gamma,0) == x]
    prob = cp.Problem(obj,constrat)
    prob.solve()

    #print("Mean Demand: ", np.sum(x.value.reshape([-1,1]) * unitsordered_Tr))
    return x.value, np.sum(x.value.reshape([-1,1]) * cost_hist), np.sum(pmf_demand * cost_hist)

def WDRO_demand_calculate_optimistic(pmf_demand, unitsordered_Tr, price_Te0, epsilon):
    a_1=4.43965609
    a_2=6.60097822
    N = len(pmf_demand)
    cost_hist = 0.85*price_Te0*unitsordered_Tr - (a_1 + a_2) * unitsordered_Tr

    pmf_demand = pmf_demand.reshape([-1,1])
    cost_hist  = cost_hist.reshape([-1,1])
    unitsordered_Tr = unitsordered_Tr.reshape([-1,1])

    cost_unitsordered_Tr = cdist(unitsordered_Tr, unitsordered_Tr, 'sqeuclidean')
    x = cp.Variable(N)
    gamma = cp.Variable([N,N])

    obj = cp.Maximize(cost_hist.T@x)
    constrat = [gamma >=0,
                cp.sum(cp.multiply(gamma, cost_unitsordered_Tr)) <= epsilon,
                cp.sum(gamma,1) == pmf_demand.reshape([-1,]),
                cp.sum(gamma,0) == x]
    prob = cp.Problem(obj,constrat)
    prob.solve()

    #print("Mean Demand: ", np.sum(x.value.reshape([-1,1]) * unitsordered_Tr))


    return x.value, np.sum(x.value.reshape([-1,1]) * cost_hist), np.sum(pmf_demand * cost_hist)

# %%
adspend_Tr                 = my_data_sku["adspend"].to_numpy()
profit_Tr                   = my_data_sku["profit"].to_numpy()
unitsordered_Tr            = my_data_sku["unitsordered"].to_numpy()
managed_fba_stock_level_Tr = my_data_sku["managed_fba_stock_level"].to_numpy()
price_Tr                   = my_data_sku["price"].to_numpy()
comp_1_price_Tr            = my_data_sku["comp_1_price"].to_numpy()



idx_hist = np.where(unitsordered_Tr < managed_fba_stock_level_Tr)
idx_Tr   = idx_hist[0]


price_Tr_True        = price_Tr[idx_Tr]
comp_1_price_Tr_True = comp_1_price_Tr[idx_Tr]
unitsordered_Tr_True = unitsordered_Tr[idx_Tr]

sigma = 0.1
epsilon = 5


comp_1_price_Te = np.array([23.02, 23.13, 23.20, 23.38, 23.75, 25.91, 25.87, 25.86, 25.87])
adspend_Te      = np.array([17,18,15,16,17,16,15,14,14])
steps           = len(comp_1_price_Te)
price_Te_hist   = np.load("price_Te_hist.npy")




Profit_history = []
for price_Te in price_Te_hist:
    profit_hist_robust = []
    profit_hist_optimistic = []
    for i in range(steps):
        comp_1_price_Te_i, adspend_Te_i = comp_1_price_Te[i], adspend_Te[i]

        pmf_demand_Tr_Te = formulate_demand_pmf(price_Tr_True, comp_1_price_Tr_True, price_Te, comp_1_price_Te_i, sigma)
        _, profit_robust, _     = WDRO_demand_calculate(pmf_demand_Tr_Te, unitsordered_Tr_True, price_Te, epsilon**2)
        _, profit_optimistic, _ = WDRO_demand_calculate_optimistic(pmf_demand_Tr_Te, unitsordered_Tr_True, price_Te, epsilon**2)


        profit_hist_robust.append(profit_robust - adspend_Te_i)
        profit_hist_optimistic.append(profit_optimistic - adspend_Te_i)
    print("Price: {}, Robust Profit: {:.2e}, Optimistic Profit: {:.2e}, Width: {:.2e}".format(price_Te,
            np.sum(np.array(profit_hist_robust)), np.sum(np.array(profit_hist_optimistic)), np.sum(np.array(profit_hist_optimistic)) - np.sum(np.array(profit_hist_robust))))
    


    Profit_history.append([np.mean(np.array(profit_hist_robust)), np.mean(np.array(profit_hist_optimistic))])

Profit_history = np.array(Profit_history)
# Out:
# Price: 14.99, Robust Profit: 7.74e+01, Optimistic Profit: 2.30e+02, Width: 1.53e+02
# Price: 15.05, Robust Profit: 8.40e+01, Optimistic Profit: 2.42e+02, Width: 1.58e+02
# Price: 15.09, Robust Profit: 8.84e+01, Optimistic Profit: 2.49e+02, Width: 1.61e+02
# Price: 15.15, Robust Profit: 9.50e+01, Optimistic Profit: 2.60e+02, Width: 1.65e+02
# Price: 15.19, Robust Profit: 9.93e+01, Optimistic Profit: 2.68e+02, Width: 1.68e+02
# Price: 15.25, Robust Profit: 1.06e+02, Optimistic Profit: 2.79e+02, Width: 1.73e+02
# Price: 15.29, Robust Profit: 1.10e+02, Optimistic Profit: 2.86e+02, Width: 1.76e+02
# Price: 15.35, Robust Profit: 1.17e+02, Optimistic Profit: 2.98e+02, Width: 1.81e+02
# Price: 15.389999999999999, Robust Profit: 1.21e+02, Optimistic Profit: 3.05e+02, Width: 1.84e+02
# Price: 15.45, Robust Profit: 1.28e+02, Optimistic Profit: 3.16e+02, Width: 1.88e+02
# Price: 15.489999999999998, Robust Profit: 1.32e+02, Optimistic Profit: 3.24e+02, Width: 1.91e+02
# Price: 15.549999999999999, Robust Profit: 1.39e+02, Optimistic Profit: 3.35e+02, Width: 1.96e+02
# Price: 15.589999999999998, Robust Profit: 1.43e+02, Optimistic Profit: 3.42e+02, Width: 1.99e+02
# Price: 15.649999999999999, Robust Profit: 1.50e+02, Optimistic Profit: 3.53e+02, Width: 2.04e+02
# Price: 15.689999999999998, Robust Profit: 1.54e+02, Optimistic Profit: 3.61e+02, Width: 2.07e+02
# Price: 15.749999999999998, Robust Profit: 1.61e+02, Optimistic Profit: 3.72e+02, Width: 2.11e+02
# Price: 15.789999999999997, Robust Profit: 1.65e+02, Optimistic Profit: 3.79e+02, Width: 2.14e+02
# Price: 15.849999999999998, Robust Profit: 1.72e+02, Optimistic Profit: 3.91e+02, Width: 2.19e+02
# Price: 15.889999999999997, Robust Profit: 1.76e+02, Optimistic Profit: 3.98e+02, Width: 2.22e+02
# Price: 15.949999999999998, Robust Profit: 1.78e+02, Optimistic Profit: 4.05e+02, Width: 2.27e+02
# Price: 15.989999999999997, Robust Profit: 1.52e+02, Optimistic Profit: 3.82e+02, Width: 2.30e+02
# Price: 16.049999999999997, Robust Profit: 7.92e+01, Optimistic Profit: 3.13e+02, Width: 2.34e+02
# Price: 16.089999999999996, Robust Profit: 7.51e+01, Optimistic Profit: 3.12e+02, Width: 2.37e+02
# Price: 21.94999999999987, Robust Profit: 3.97e+02, Optimistic Profit: 1.08e+03, Width: 6.86e+02
# Price: 21.98999999999987, Robust Profit: 3.99e+02, Optimistic Profit: 1.09e+03, Width: 6.89e+02
# Price: 22.04999999999987, Robust Profit: 4.03e+02, Optimistic Profit: 1.10e+03, Width: 6.93e+02
# Price: 22.08999999999987, Robust Profit: 4.05e+02, Optimistic Profit: 1.10e+03, Width: 6.96e+02
# Price: 22.149999999999867, Robust Profit: 4.09e+02, Optimistic Profit: 1.11e+03, Width: 7.01e+02
# Price: 22.189999999999866, Robust Profit: 4.11e+02, Optimistic Profit: 1.11e+03, Width: 7.04e+02
# Price: 22.249999999999865, Robust Profit: 4.15e+02, Optimistic Profit: 1.12e+03, Width: 7.08e+02
# Price: 22.289999999999864, Robust Profit: 4.17e+02, Optimistic Profit: 1.13e+03, Width: 7.12e+02
# Price: 22.349999999999863, Robust Profit: 4.21e+02, Optimistic Profit: 1.14e+03, Width: 7.16e+02
# Price: 22.389999999999862, Robust Profit: 4.25e+02, Optimistic Profit: 1.14e+03, Width: 7.19e+02
# Price: 22.44999999999986, Robust Profit: 4.32e+02, Optimistic Profit: 1.16e+03, Width: 7.24e+02
# Price: 22.48999999999986, Robust Profit: 4.40e+02, Optimistic Profit: 1.17e+03, Width: 7.27e+02
# Price: 22.54999999999986, Robust Profit: 4.50e+02, Optimistic Profit: 1.18e+03, Width: 7.31e+02
# Price: 22.589999999999858, Robust Profit: 4.56e+02, Optimistic Profit: 1.19e+03, Width: 7.34e+02
# Price: 22.649999999999856, Robust Profit: 4.61e+02, Optimistic Profit: 1.20e+03, Width: 7.39e+02
# Price: 22.689999999999856, Robust Profit: 4.64e+02, Optimistic Profit: 1.21e+03, Width: 7.42e+02
# Price: 22.749999999999854, Robust Profit: 4.68e+02, Optimistic Profit: 1.21e+03, Width: 7.47e+02
# Price: 22.789999999999853, Robust Profit: 4.71e+02, Optimistic Profit: 1.22e+03, Width: 7.50e+02
# Price: 22.849999999999852, Robust Profit: 4.77e+02, Optimistic Profit: 1.23e+03, Width: 7.54e+02
# Price: 22.88999999999985, Robust Profit: 4.82e+02, Optimistic Profit: 1.24e+03, Width: 7.57e+02
# Price: 22.94999999999985, Robust Profit: 4.94e+02, Optimistic Profit: 1.26e+03, Width: 7.62e+02
# Price: 22.98999999999985, Robust Profit: 5.02e+02, Optimistic Profit: 1.27e+03, Width: 7.65e+02
# Price: 23.049999999999848, Robust Profit: 5.12e+02, Optimistic Profit: 1.28e+03, Width: 7.70e+02
# Price: 23.089999999999847, Robust Profit: 5.20e+02, Optimistic Profit: 1.29e+03, Width: 7.73e+02
# Price: 23.149999999999846, Robust Profit: 5.32e+02, Optimistic Profit: 1.31e+03, Width: 7.77e+02
# Price: 23.189999999999845, Robust Profit: 5.38e+02, Optimistic Profit: 1.32e+03, Width: 7.80e+02
# Price: 23.249999999999844, Robust Profit: 5.44e+02, Optimistic Profit: 1.33e+03, Width: 7.85e+02
# Price: 23.289999999999843, Robust Profit: 5.49e+02, Optimistic Profit: 1.34e+03, Width: 7.88e+02
# Price: 23.34999999999984, Robust Profit: 5.57e+02, Optimistic Profit: 1.35e+03, Width: 7.93e+02
# Price: 23.38999999999984, Robust Profit: 5.65e+02, Optimistic Profit: 1.36e+03, Width: 7.96e+02
# Price: 23.44999999999984, Robust Profit: 5.75e+02, Optimistic Profit: 1.38e+03, Width: 8.00e+02
# Price: 23.48999999999984, Robust Profit: 5.80e+02, Optimistic Profit: 1.38e+03, Width: 8.03e+02
# Price: 23.549999999999837, Robust Profit: 5.85e+02, Optimistic Profit: 1.39e+03, Width: 8.08e+02
# Price: 23.589999999999836, Robust Profit: 5.88e+02, Optimistic Profit: 1.40e+03, Width: 8.11e+02
# Price: 23.649999999999835, Robust Profit: 5.92e+02, Optimistic Profit: 1.41e+03, Width: 8.16e+02
# Price: 23.689999999999834, Robust Profit: 5.95e+02, Optimistic Profit: 1.41e+03, Width: 8.19e+02
# Price: 23.749999999999833, Robust Profit: 5.99e+02, Optimistic Profit: 1.42e+03, Width: 8.23e+02
# Price: 23.789999999999832, Robust Profit: 6.02e+02, Optimistic Profit: 1.43e+03, Width: 8.26e+02
# Price: 23.84999999999983, Robust Profit: 6.06e+02, Optimistic Profit: 1.44e+03, Width: 8.31e+02
# Price: 23.88999999999983, Robust Profit: 6.09e+02, Optimistic Profit: 1.44e+03, Width: 8.34e+02
# Price: 23.94999999999983, Robust Profit: 6.13e+02, Optimistic Profit: 1.45e+03, Width: 8.39e+02
# Price: 23.989999999999828, Robust Profit: 6.15e+02, Optimistic Profit: 1.46e+03, Width: 8.42e+02

# %%
Pricing_Record     = np.concatenate([price_Te_hist.reshape([-1,1]),
                                Profit_history], axis=1)

np.savetxt('Week1_pricing.csv', Pricing_Record, delimiter=',', header='Price,Robust,Optimistic', comments='')

# %%
plt.rcParams["font.family"] = "arial"
plt.style.use("ggplot")
fig, axes = plt.subplots(figsize=(6,6))


axes.plot(price_Te_hist, Profit_history[:,0], label=r'Robust Profit', 
            linestyle = '-.', marker = '>', color='blue',ms=8,linewidth=3)
axes.plot(price_Te_hist, Profit_history[:,1], label=r'Optimistic Profit', 
            linestyle = '-', marker = 'o', color='r',ms=8,linewidth=3,alpha=0.4)

axes.legend(loc="best",fontsize=25)
axes.set_xlabel(r'Price $p$', fontsize=18)
axes.set_ylabel(r'Estimated Profit', fontsize=18)

plt.xticks(fontsize=25)
plt.yticks(fontsize=25)

axes.set_yticks([0,40,80,120,160])
plt.savefig("price_week1.pdf",bbox_anchor="tight")

# %% [markdown]
# ### Predicted Profit for Week1

# %%
sigma    = 0.1
epsilon  = 5
price_Te = 18.29

profit_hist_robust = []
profit_hist_optimistic = []
for i in range(steps):
    comp_1_price_Te_i, adspend_Te_i = comp_1_price_Te[i], adspend_Te[i]
    
    pmf_demand_Tr_Te = formulate_demand_pmf(price_Tr_True, comp_1_price_Tr_True, price_Te, comp_1_price_Te_i, sigma)
    _, profit_robust, _     = WDRO_demand_calculate(pmf_demand_Tr_Te, unitsordered_Tr_True, price_Te, epsilon**2)
    _, profit_optimistic, _ = WDRO_demand_calculate_optimistic(pmf_demand_Tr_Te, unitsordered_Tr_True, price_Te, epsilon**2)

    
    profit_hist_robust.append(profit_robust - adspend_Te_i)
    profit_hist_optimistic.append(profit_optimistic - adspend_Te_i)

print(profit_hist_robust)
print(profit_hist_optimistic)
